# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import torch.optim as optim
import os
import torchvision
import torchvision.transforms as transforms

# %%
#BasicBlock class 정의
class BasicBlock(nn.Module):
    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()

        # 3x3 필터를 사용 (너비와 높이를 줄일 때는 stride 값 조절)
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes) # 배치 정규화(batch normalization)

        # 3x3 필터를 사용 (패딩을 1만큼 주기 때문에 너비와 높이가 동일)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes) # 배치 정규화(batch normalization)

        self.shortcut = nn.Sequential() # identity인 경우
        if stride != 1: # stride가 1이 아니라면, Identity mapping이 아닌 경우
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x) # (핵심) skip connection
        out = F.relu(out)
        return out

# %%
# ResNet 클래스 정의
class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 64

        # 64개의 3x3 필터(filter)를 사용
        self.conv1 = nn.Conv2d(1, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes # 다음 레이어를 위해 채널 수 변경
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

# %%
# ResNet18 함수 정의
def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])

# %%
transform_train = transforms.Compose([
    transforms.ToTensor(),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
])

train_dataset = torchvision.datasets.MNIST(root='./data', train=True, download=True, transform=transform_train)
test_dataset = torchvision.datasets.MNIST(root='./data', train=False, download=True, transform=transform_test)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=4)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=100, shuffle=False, num_workers=4)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw
# Processing...
# Done!
# /usr/local/lib/python3.6/dist-packages/torchvision/datasets/mnist.py:480: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)

# %%
device = 'cuda'

net = ResNet18()
net = net.to(device)
net = torch.nn.DataParallel(net)
cudnn.benchmark = True

learning_rate = 0.01
file_name = 'resnet18_mnist.pt'

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)


def train(epoch):
    print('\n[ Train epoch: %d ]' % epoch)
    net.train()
    train_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()

        benign_outputs = net(inputs)
        loss = criterion(benign_outputs, targets)
        loss.backward()

        optimizer.step()
        train_loss += loss.item()
        _, predicted = benign_outputs.max(1)

        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()
        
        if batch_idx % 100 == 0:
            print('\nCurrent batch:', str(batch_idx))
            print('Current benign train accuracy:', str(predicted.eq(targets).sum().item() / targets.size(0)))
            print('Current benign train loss:', loss.item())

    print('\nTotal benign train accuarcy:', 100. * correct / total)
    print('Total benign train loss:', train_loss)


def test(epoch):
    print('\n[ Test epoch: %d ]' % epoch)
    net.eval()
    loss = 0
    correct = 0
    total = 0

    for batch_idx, (inputs, targets) in enumerate(test_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        total += targets.size(0)

        outputs = net(inputs)
        loss += criterion(outputs, targets).item()

        _, predicted = outputs.max(1)
        correct += predicted.eq(targets).sum().item()

    print('\nTest accuarcy:', 100. * correct / total)
    print('Test average loss:', loss / total)

    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print('Model Saved!')


def adjust_learning_rate(optimizer, epoch):
    lr = learning_rate
    if epoch >= 5:
        lr /= 10
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# %%
for epoch in range(0, 10):
    adjust_learning_rate(optimizer, epoch)
    train(epoch)
    test(epoch)
# Out:
# [ Train epoch: 0 ]
#
# Current batch: 0
# Current benign train accuracy: 0.1171875
# Current benign train loss: 2.3753178119659424
#
# Current batch: 100
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.06749163568019867
#
# Current batch: 200
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.055824875831604004
#
# Current batch: 300
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.029643958434462547
#
# Current batch: 400
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.022336214780807495
#
# Total benign train accuarcy: 96.26
# Total benign train loss: 57.10986548732035
#
# [ Test epoch: 0 ]
#
# Test accuarcy: 98.76
# Test average loss: 0.00039501850174565334
# Model Saved!
#
# [ Train epoch: 1 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.01649112068116665
#
# Current batch: 100
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.05668893828988075
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.01504975650459528
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.011261612176895142
#
# Current batch: 400
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.02801239676773548
#
# Total benign train accuarcy: 99.24166666666666
# Total benign train loss: 11.624388039752375
#
# [ Test epoch: 1 ]
#
# Test accuarcy: 99.01
# Test average loss: 0.0002962226536066737
# Model Saved!
#
# [ Train epoch: 2 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.013623804785311222
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.007023715879768133
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0034345064777880907
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.002506110817193985
#
# Current batch: 400
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.0688888356089592
#
# Total benign train accuarcy: 99.58333333333333
# Total benign train loss: 6.404719934624154
#
# [ Test epoch: 2 ]
#
# Test accuarcy: 99.25
# Test average loss: 0.00023780222401110221
# Model Saved!
#
# [ Train epoch: 3 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0021138349547982216
#
# Current batch: 100
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.013716950081288815
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.001186832902021706
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0007195536745712161
#
# Current batch: 400
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.01976167783141136
#
# Total benign train accuarcy: 99.71833333333333
# Total benign train loss: 4.123158910748316
#
# [ Test epoch: 3 ]
#
# Test accuarcy: 99.28
# Test average loss: 0.0002334277853326057
# Model Saved!
#
# [ Train epoch: 4 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0006715425406582654
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0006790312472730875
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.004995640367269516
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0037526015657931566
#
# Current batch: 400
# Current benign train accuracy: 1.0
# Current benign train loss: 0.004768946208059788
#
# Total benign train accuarcy: 99.855
# Total benign train loss: 2.3008563640978537
#
# [ Test epoch: 4 ]
#
# Test accuarcy: 99.28
# Test average loss: 0.00020572612173891684
# Model Saved!
#
# [ Train epoch: 5 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.00025657936930656433
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0003754862700589001
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0013256974052637815
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0004702356527559459
#
# Current batch: 400
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0006721388199366629
#
# Total benign train accuarcy: 99.96333333333334
# Total benign train loss: 0.8493336958345026
#
# [ Test epoch: 5 ]
#
# Test accuarcy: 99.45
# Test average loss: 0.00016077767865172064
# Model Saved!
#
# [ Train epoch: 6 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0008193310350179672
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.00024652457796037197
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0002736866008490324
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0007564957486465573
#
# Current batch: 400
# Current benign train accuracy: 1.0
# Current benign train loss: 0.00030951006920076907
#
# Total benign train accuarcy: 99.98833333333333
# Total benign train loss: 0.500260587396042
#
# [ Test epoch: 6 ]
#
# Test accuarcy: 99.48
# Test average loss: 0.0001572539378374586
# Model Saved!
#
# [ Train epoch: 7 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0008397611672990024
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0004242810537107289
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.00033868051832541823
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0005468568997457623
#
# Current batch: 400
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0006915969424881041
#
# Total benign train accuarcy: 99.99
# Total benign train loss: 0.4125782443516073
#
# [ Test epoch: 7 ]
#
# Test accuarcy: 99.5
# Test average loss: 0.0001535381700225571
# Model Saved!
#
# [ Train epoch: 8 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.000511980033479631
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.00021528947399929166
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.00023120659170672297
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0005533607909455895
#
# Current batch: 400
# Current benign train accuracy: 1.0
# Current benign train loss: 0.00047764283954165876
#
# Total benign train accuarcy: 99.99833333333333
# Total benign train loss: 0.30338971007586224
#
# [ Test epoch: 8 ]
#
# Test accuarcy: 99.49
# Test average loss: 0.0001560536291759945
# Model Saved!
#
# [ Train epoch: 9 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0013457478489726782
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0004303256864659488
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0009816341334953904
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0003565613296814263
#
# Current batch: 400
# Current benign train accuracy: 1.0
# Current benign train loss: 0.00018160963372793049
#
# Total benign train accuarcy: 99.99666666666667
# Total benign train loss: 0.2956691746840079
#
# [ Test epoch: 9 ]
#
# Test accuarcy: 99.51
# Test average loss: 0.00015181326474721573
# Model Saved!
